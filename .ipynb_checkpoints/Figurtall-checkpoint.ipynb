# %% [markdown]
# # Figurtall ved hjelp av løkker

# %% [markdown]
# I denne læringsaktiviteten skal vi repetere løkker og lister. Vi bruker siden dette til å løse oppgaver om figurtall.

# %% [markdown]
# #### for-løkker og tallfølger
# Når vi vil at et program skal gjøre samme oppgave flere ganger lager vi løkker. Dersom vi på forhånd vet hvor mange ganger vi ønsker løkken skal kjøres bruker vi en for-løkke. I python er det mange måter å kjøre for-løkker på, men en av de vanligste er å bruke kommandoen '`range(start,stopp,hopp)`

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b>Før du kjører kodensnutten i cellen under, hva tror du blir output?</div>

# %% [markdown]
# Skriv her:

# %%
antall=int(input("hvor mange tall?"))

for n in range(1,antall + 1):  # hvorfor + 1 tror du?
    print(n)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b>Kopier koden og gjør små endringer slik at koden etter tur: starter på null, bare skriver ut oddetall og teller baklengs dvs starter med et høyt tall, ender på et lavt og hopper med negative tall. </div>

# %% [markdown]
# #### Tegning av trekanttall

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b>Kopier den opprinnelige koden fra første oppgave og lim den inn under. Forandre det som står inne i printkommandoen til: <b>n * " *"</b>. Kjør koden og forklar hva som skjer. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b> Kopier koden din til neste ledige celle og se om du kan endre den slik at den tegner figurene dine slik at de ligner eksempelet under. <b>Hint: </b> print(" "* <b>du må lage noe matematikk med n her</b>,n*" *") </div>

# %% [markdown]
# ![image.png](attachment:bae5fbe9-b54f-416c-babe-73a9857416f5.png)

# %% [markdown]
# #### Trekanttall - fra ett tall til neste
# ![image.png](attachment:8b0ee093-3682-450e-ba4c-c40e6faa2d16.png)
#
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b> Undersøk figuren og forklar hvordan verdien øker fra et trekanttall til neste. Med andre ord hva er sammenhengen mellom trekanttallene og de natrulige tallene? </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b> Vi gjør noen få forandringer på det første programmet slik at vi kan regne ut trekanttall ved hjelp av sammenhengen mellom trekanttallene og de naturlige tallene som du har funnet. Jeg har begynt, du må fullføre. </div>

# %%
antall = int(input("hvor mange tall?"))

Trekant = 0 #setter verdien av trekanttall lik null før vi starer å bygge opp

for n in range(1,antall + 1):
    Trekant =               # Her må DU skrive kode som bygger opp et og et trekanttall,
                            # bruk verdien av det forrige tallet legg til ny rad av figuren. 
    print(Trekant)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b> Når du har fått koden over til å fungere, kopier den til neste ledig celle og gjør en liten forandring slik at kun det siste tallet som regnes ut blir skrevet til skjerm.  </div>

# %% [markdown]
# #### Her er en oppgave fra boken:
# ![image.png](attachment:a92445b5-c485-465a-b846-069bebcdc782.png)
# * Klarer du å bearbeide kodene over slik at du får tegnet figuren slik som i oppgaven **og** telt opp slik at du kan svare på oppgave a)?
# * b-oppgaven trenger du å repetere litt om while-løkker for å svare på.

# %% [markdown]
# ### while løkker:
# Når man på forhånd ikke vet hvor mange ganger man trenger å kjøre løkken kan man lage en while-løkke.
# Denne løkken går *så lenge* et vilkår er sant. while løkker trenger at variablen som skal sjekkes er gitt på forhånd og at variabelen endres inni løkken slik at løkken til slutt stopper.
#
# <div class="alert alert-block alert-warning">
# <b>Eksempel: </b>Lag en løkke som så lenge et tall er positivt, skriver ut tallet, trekker fra 2 og gjentar.  </div>

# %%
tall = 15  #variabelen talldefineres og gies en verdi FØR løkken 

while tall>0: # så lenge variabelen er større enn null, kjører løkken.
    print(tall)
    tall -= 2 #python for: ta det opprinnelige tallet, trekk fra to og oppdater variabelen 'tall' 
                # Hva tror du += gjør?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b>Lek litt med koden over, før du lager en en egen while løkke som begynner med n = 1 og skriver ut alle <b>kubiktall</b> som er mindre enn 2000  <b> hint:</b> n**3 regner ut n i tredje</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b>Nå kan du gå tilbake og gjøre oppgave  1.141 b) </div>

# %% [markdown]
# ### Lister
# Ofte er det lurt å ta vare på resultatene vi lager i en liste. Her lærer du å lage og fylle en liste.
# <div class="alert alert-block alert-warning">
# <b>Eksempel: </b>Lag en tom liste med navnet 'minliste', legg inn tallene 1,2,3, ... ,10 og
# skriv resultatet til skjerm  </div>

# %%
antall = 10
minliste =[] # firkant paranteser for liste, denne er tom

for i in range(1,antall + 1):
    minliste.append(i)  # På minliste, bruk listemetoden append. 
                        # Den legger til det vi har i parantesen til slutt i listen
print(minliste) # skriver ut resultatet

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b>Hva tror du koden under gjør? Test </div>

# %%
sum(minliste)

# %% [markdown]
# #### Summen av trekanttall
# ![image.png](attachment:8b0ee093-3682-450e-ba4c-c40e6faa2d16.png)
#
# <div class="alert alert-block alert-info">
# <b>Oppgave: </b> Ta utgangspunkt i tidligere kode, lag et program som lager en liste med de ti første trekanttallene og finn ut hvor mange knapper du trenger for å lage alle ti tallene samtidig. </div>

# %% [markdown]
# ### Her en oppgave fra boken, gjør a,b og c for hånd:
# ![image.png](attachment:e697e7fd-a8f1-4946-9532-fa7bcefe0b50.png)
#
# #### d- oppgaven kan derimot løses med koding, jeg har begynt litt slik at du kan fullføre.
#
# ![image.png](attachment:56ee3e79-aeaa-4866-8dab-0f67018d81a1.png)
#
# **Ekstra spørsmål:**
# Hvor mange kort ble til overs?

# %%
n = 0
kort_pr_etasje = []

while sum(kort_pr_etasje) < 500:
    n += 1 # begynn på ny etasje
    
    # her må du skrive kode som regner ut antall kort pr. etasje, husk gulv/tak
    
    kort_pr_etasje.append() # husk å putte noe inn i parantesen
    

# husk å skrive ut og sjekke svar. Dvs hvor mange etasjer, hvor mange kort tilsammen 
# og hvormange av de 500 kortene ble ikke brukt 
# Dersom du ikke helt får svaret til å stemme sjekk hintet under.

# %% [markdown]
# ### Hjelp om løkken går en gang for mye
# I koden under har vi lekt litt med en liste og en teller. Kanskje forstår du hvordan du kan korigere svaret ditt over dersom while løkken kjører en ekstra gang. Kan du bruke denne metoden i koden over, slik at resultatet blir riktig?

# %%
# la oss si at dette er resultatet etter en løkke som har kjørt en gang for mye:
n = 5
liste = [0,1,2,3,4]
print('Verdier før endring')
print(n)
print(liste)

# etter at vi sjekker resultatet, kan vi korrigerer litt:
n = n-1     # Ruller telleren tilbake ett hakk 
liste.pop() # 'pop' ut det siste elementet i listen slik at listen blir et element kortere
print('\nVerdier etter endring') #\n betyr "ny linje" slik at det blir luft i det som printes ut.
print(n)
print(liste)
# Out:
# Verdier før endring
# 5
# [0, 1, 2, 3, 4]
#
# Verdier etter endring
# 4
# [0, 1, 2, 3]

# %% [markdown]
# # En oppgave til
# Nå med mindre hjelp :)
# ![image.png](attachment:033f7585-a341-4153-a3c1-3befb7c9a3ad.png)
#
# Over ser du de første tre figurtallene i en serie laget med fyrstikker. La oss kalle dem fyrstikktallene. Antall fyrstikker i hver av de tre figurene gir $F_1,F_2$ og $F_3$
#
# **Dersom du fortsetter mønsteret hvor mange fyrstikker trenger du for å lage den fjerde figuren. Med andre ord, hva er $F_4$?**

# %% [markdown]
# **Systematiser opplysningen i en tabell. Jeg har begynt, dobbelklik i denne cellen og fullfør**
# |$n$|$n^2$|$F_n$|
# |---|---|---|
# |1|1|4|
# |2|4||
#
# **Finner mønsteret mellom figurtallet og hvilket nummer i rekken det er.**
# Med ander ord: finner du en formel for $F_n$?

# %% [markdown]
# **Bruk svaret fra i sted til å fullføre koden under:**

# %%
n = int(input("Hvilket fyrstikktall ønsker du å beregne?"))

Fn = 
print(Fn)

# %% [markdown]
# * **kjør koden og sjekk at den stemmer med $F_1, F_2$ og $F_3$ fra figuren.**
# * **Hvor mange fyrstikker trenger du for å lage $F_{20}$?**

# %% [markdown]
# Nå ønsker du å ikke legge ett og ett tall, men lage alle tallene fra det første og opp til en gitt verdi n.
#
# **Fullfør koden under for å lage et program som forteller deg hvor mange fyrstikker du trenger for å legge de n første fyrstikktallene**

# %%
antall = int(input("Hvor mange fyrstikktall ønsker du å legge?"))
n = 0 
tilsammen = 0

while n<antall: #her kunne du brukt en for-løkke, men du trenger en while-løkke seinere i oppgaven
        n = n + 1 
        Fn = #fullfør denne linjen
        tilsammen = #fullfør denne linjen
        
print(f'Du trenger {tilsammen} fystikker for å lage de {antall} første tallene')

# %% [markdown]
# * **Bruk figuren i starten av oppgaven til å sjekke at programmet regner riktig.**
# * **Hvor mange fyrstikker trengs for å legge de 10 første fyrstikktallene?**

# %% [markdown]
# ### Utfordring
# Figuren av toppen av oppgaven stammer fra en eksamensoppgave her er teksten som hører til oppgaven:
# ![image.png](attachment:7e58f226-7bf3-48f1-8923-267c8932b482.png)
#
# **Kan du med utgangspunkt i det forrige programmet, lage et program som svarer på eksamensoppgaven?**
#
# Hint:
# * du trenger en annen variabel som input
# * du trenger en ny test i løkken
# * du må korrigere svaret når løkken er ferdig kjørt før du skriver det ut
#   * det betyr at det er viktig å teste programmet opp mot figuren i starten. Dvs får du rett svar med 20 fyrstikker eller 16?
#
#
# **Lykke til!**
