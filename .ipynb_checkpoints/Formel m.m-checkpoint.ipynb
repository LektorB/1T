# %% [markdown]
# # Øving til Heldagsprøven i 1T
# ## Snu en formel
#
# ![image.png](attachment:9a4cbf34-695b-45c9-bf7b-88af97b8e32d.png)
#
# Gitt formelen for sylinder har jeg laget programmet under til inspirasjon

# %%
# importerer bibliotek pga pi
import numpy as np
radius = 5
høyde = 17

Volum = np.pi*radius**2*høyde # bruker pi fra biblioteket numpy

print(Volum)

# %% [markdown]
# Nå kan du snu formelen og lag et tilsvarende program som regner ut radius dersom man kjenner volum og høyde. Velg selv tall til å teste programmet ditt. Du kan få bruk for `np.sqrt()`

# %% [markdown]
# # Likningssett med Ada
# Oppgaven under ble gitt som den siste oppgaven på eksamen 10. klasse våren 2017
# ![image.png](attachment:528e612d-38a6-4ac7-b974-0c8fe7eda1a3.png)
#
# **Oppgave a til c** løser du med penn og papir
#
# **d)** Skriv et program som løser likningen og skriver ut løsningen. **Jeg har startet.**

# %%
# likning 1
a, b, c = 5, 4, 9 

# likning 2
d, e, f = 6, 7, 13

# %% [markdown]
# **e)** Forsøk programmet ditt følgende likningssett:
# $$
# \begin{bmatrix}
# -2x + 4y = 10 \\
# x - 2y = 8
# \end{bmatrix}
# $$
#
# **f)** Kan du forklare hvorfor programmet krasjer?
# Både algebraisk og geometrisk?

# %% [markdown]
# ## Formel for en linje gjennom to punkt.
# Fyll inn de to linjene som regner ut a og b

# %%
# Skriv inn koordinatene til to punkt
x1, y1 = (2,4)
x2, y2 = (1,1)

if x1 == x2:
    print(f'Dette er en loddrett linje med likning x = {x1}')
else:
    a =  # Du må fylle inn disse to linjene
    b = 

    print(f'Linjen har stigningstall a = {a} og konstantledd b = {b}')

# %% [markdown]
# ## Eksamensoppgave med løkke
# Oppgaven under er gitt som eksamensoppgave i 1T.
# Undersøk logiken i figurene og lag ulike løkker slik at du kan svare på spørsmålene.
#
# **NB** Husk å teste programmene dine med kjente tall.
#
# ![image.png](attachment:4686eff6-cf3f-48f7-a001-83bae00a6c4d.png)

# %% [markdown]
# ## Andregradsanalyastor
# Lag et program som tar inn a,b og c fra en andragradsfunksjon av typen $f(x)=ax^2+bx+c$ og beskriver egenskapene til denne. f.eks.
# topp eller bunnpunkt, evt nullpunkter. skjæring med y-aksen osv.
#
# Trenger du en ekstra utfordring plot f(x) og f'(x) automatisk.
#
# Enda en utfordring? Marker de viktige punktene med forklaring.
